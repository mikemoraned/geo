# %%
# %matplotlib inline

# %%
from esa_climate_toolbox.core import list_ecvs

list_ecvs()
# Out:
# ['LAKES',
#  'LC',
#  'SST',
#  'ICESHEETS',
#  'SEASTATE',
#  'AEROSOL',
#  'SEALEVEL',
#  'OZONE',
#  'LST',
#  'VEGETATION',
#  'SEAICE',
#  'WATERVAPOUR',
#  'CLOUD',
#  'PERMAFROST',
#  'OC',
#  'RD',
#  'BIOMASS',
#  'FIRE',
#  'SNOW',
#  'SOILMOISTURE',
#  'SEASURFACESALINITY',
#  'GHG']

# %%
from esa_climate_toolbox.core import list_ecv_datasets

list_ecv_datasets("SNOW")
# Out:
# [('esacci.SNOW.day.L3C.SCFG.AATSR.Envisat.AATSR_ENVISAT.v1-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.ATSR-2.ERS-2.ATSR2_ERS2.v1-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-2.NOAA-11.AVHRR_NOAA11.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-2.NOAA-12.AVHRR_NOAA12.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-2.NOAA-14.AVHRR_NOAA14.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-2.NOAA-7.AVHRR_NOAA7.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-2.NOAA-9.AVHRR_NOAA9.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-3.Metop-A.AVHRR_METOPA.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-3.Metop-B.AVHRR_METOPB.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-3.Metop-C.AVHRR_METOPC.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-3.NOAA-16.AVHRR_NOAA16.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-3.NOAA-17.AVHRR_NOAA17.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-3.NOAA-18.AVHRR_NOAA18.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR-3.NOAA-19.AVHRR_NOAA19.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR.NOAA-10.AVHRR_NOAA10.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR.NOAA-6.AVHRR_NOAA6.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR.NOAA-8.AVHRR_NOAA8.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.AVHRR.TIROS-N.AVHRR_TIROSN.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.MODIS.Terra.MODIS_TERRA.2-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.MODIS.Terra.MODIS_TERRA.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFG.multi-sensor.multi-platform.AVHRR_MERGED.2-0.r1',
#   'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AATSR.Envisat.AATSR_ENVISAT.v1-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.ATSR-2.ERS-2.ATSR2_ERS2.v1-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-2.NOAA-11.AVHRR_NOAA11.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-2.NOAA-12.AVHRR_NOAA12.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-2.NOAA-14.AVHRR_NOAA14.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-2.NOAA-7.AVHRR_NOAA7.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-2.NOAA-9.AVHRR_NOAA9.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-3.Metop-A.AVHRR_METOPA.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-3.Metop-B.AVHRR_METOPB.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-3.Metop-C.AVHRR_METOPC.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-3.NOAA-16.AVHRR_NOAA16.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-3.NOAA-17.AVHRR_NOAA17.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-3.NOAA-18.AVHRR_NOAA18.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR-3.NOAA-19.AVHRR_NOAA19.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR.NOAA-10.AVHRR_NOAA10.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR.NOAA-6.AVHRR_NOAA6.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR.NOAA-8.AVHRR_NOAA8.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.AVHRR.TIROS-N.AVHRR_TIROSN.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.MODIS.Terra.MODIS_TERRA.2-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.MODIS.Terra.MODIS_TERRA.3-0.r1', 'esa-cci'),
#  ('esacci.SNOW.day.L3C.SCFV.multi-sensor.multi-platform.AVHRR_MERGED.2-0.r1',
#   'esa-cci'),
#  ('esacci.SNOW.day.L3C.SWE.multi-sensor.multi-platform.MERGED.2-0.r1',
#   'esa-cci'),
#  ('esacci.SNOW.day.L3C.SWE.multi-sensor.multi-platform.MERGED.3-1.r1',
#   'esa-cci'),
#  ('esacci.SNOW.day.L3S.SCFG.multi-sensor.multi-platform.MERGED.1-0.r1',
#   'esa-cci'),
#  ('ESACCI-L3C_SNOW-SCFG-AATSR_ENVISAT-20020520-20120408-fv1.0_kr1.0',
#   'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SCFG-ATSR-2_ERS-2-19950801-20030622-fv1.0_kr1.0',
#   'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SCFG-MODIS_TERRA-20000224-20201231-fv2.0_kr1.0',
#   'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SCFG-AVHRR_MERGED-19820101-20181230-fv2.0_kr1.0',
#   'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SCFV-AATSR_ENVISAT-20020520-20120408-fv1.0_kr1.0',
#   'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SCFV-ATSR-2_ERS-2-19950801-20030622-fv1.0_kr1.0',
#   'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SCFV-MODIS_TERRA-20000224-20201231-fv2.0_kr1.0',
#   'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SCFV-AVHRR_MERGED-19820101-20181230-fv2.0_kr1.0',
#   'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SWE-MERGED-19790102-20200524-fv2.0_kr1.2', 'esa-cci-kc'),
#  ('ESACCI-L3S_SNOW-SCFG-MERGED-CRYOCLIM-19820101-2019_kr1.0', 'esa-cci-kc'),
#  ('ESACCI-L3C_SNOW-SWE-1979-2018-fv1.0.zarr', 'esa-cci-zarr'),
#  ('ESACCI-L3C_SNOW-SWE-1979-2020-fv2.0.zarr', 'esa-cci-zarr')]

# %%
from esa_climate_toolbox.core import open_data

# %%
dataset, id = open_data('ESACCI-L3C_SNOW-SWE-1979-2020-fv2.0.zarr')

# %%
dataset
# Out:
# <xarray.Dataset> Size: 823GB
# Dimensions:   (time: 7934, lat: 1800, lon: 3600, nv: 2)
# Coordinates:
#   * lat       (lat) float64 14kB -89.95 -89.85 -89.75 ... 89.75 89.85 89.95
#     lat_bnds  (lat, nv) float64 29kB dask.array<chunksize=(900, 2), meta=np.ndarray>
#   * lon       (lon) float64 29kB -179.9 -179.8 -179.8 ... 179.7 179.8 179.9
#     lon_bnds  (lon, nv) float64 58kB dask.array<chunksize=(900, 2), meta=np.ndarray>
#   * time      (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24
# Dimensions without coordinates: nv
# Data variables:
#     swe       (time, lat, lon) float64 411GB dask.array<chunksize=(10, 900, 900), meta=np.ndarray>
#     swe_std   (time, lat, lon) float64 411GB dask.array<chunksize=(10, 900, 900), meta=np.ndarray>
# Attributes: (12/43)
#     Conventions:                CF-1.9
#     cdm_data_type:              grid
#     comment:                    The following auxiliary datasets are used for...
#     creator_email:              kari.luojus@fmi.fi (Scientific and Production...
#     creator_name:               Finnish Meteorological Institute
#     creator_url:                www.fmi.fi
#     ...                         ...
#     time_coverage_duration:     P1D
#     time_coverage_end:          20200524T000000Z
#     time_coverage_resolution:   P1D
#     time_coverage_start:        19790102T000000Z
#     title:                      ESA CCI snow SWE product level L3C daily, Dyn...
#     tracking_id:                25063fb5-47ad-424a-8f26-29bdf35efb78

# %%
dataset["time"]
# Out:
# <xarray.DataArray 'time' (time: 7934)> Size: 63kB
# array(['1979-01-02T00:00:00.000000000', '1979-01-04T00:00:00.000000000',
#        '1979-01-06T00:00:00.000000000', ..., '2020-05-15T00:00:00.000000000',
#        '2020-05-20T00:00:00.000000000', '2020-05-24T00:00:00.000000000'],
#       shape=(7934,), dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24
# Attributes:
#     axis:           T
#     long_name:      time
#     standard_name:  time

# %%
dataset["lat"]
# Out:
# <xarray.DataArray 'lat' (lat: 1800)> Size: 14kB
# array([-89.95, -89.85, -89.75, ...,  89.75,  89.85,  89.95], shape=(1800,))
# Coordinates:
#   * lat      (lat) float64 14kB -89.95 -89.85 -89.75 ... 89.75 89.85 89.95
# Attributes:
#     axis:           Y
#     bounds:         lat_bnds
#     long_name:      WGS84 latitude coordinates, center of pixel
#     standard_name:  latitude
#     units:          degree_north

# %%
dataset["lon"]
# Out:
# <xarray.DataArray 'lon' (lon: 3600)> Size: 29kB
# array([-179.95, -179.85, -179.75, ...,  179.75,  179.85,  179.95],
#       shape=(3600,))
# Coordinates:
#   * lon      (lon) float64 29kB -179.9 -179.8 -179.8 ... 179.7 179.8 179.9
# Attributes:
#     axis:           X
#     bounds:         lon_bnds
#     long_name:      WGS84 longitude coordinates, center of pixel
#     standard_name:  longitude
#     units:          degree_east

# %%
dataset.sel(time='2000-07-01 12:00:00', method='nearest')
# Out:
# <xarray.Dataset> Size: 104MB
# Dimensions:   (lat: 1800, lon: 3600, nv: 2)
# Coordinates:
#   * lat       (lat) float64 14kB -89.95 -89.85 -89.75 ... 89.75 89.85 89.95
#     lat_bnds  (lat, nv) float64 29kB dask.array<chunksize=(900, 2), meta=np.ndarray>
#   * lon       (lon) float64 29kB -179.9 -179.8 -179.8 ... 179.7 179.8 179.9
#     lon_bnds  (lon, nv) float64 58kB dask.array<chunksize=(900, 2), meta=np.ndarray>
#     time      datetime64[ns] 8B 2000-05-23
# Dimensions without coordinates: nv
# Data variables:
#     swe       (lat, lon) float64 52MB dask.array<chunksize=(900, 900), meta=np.ndarray>
#     swe_std   (lat, lon) float64 52MB dask.array<chunksize=(900, 900), meta=np.ndarray>
# Attributes: (12/43)
#     Conventions:                CF-1.9
#     cdm_data_type:              grid
#     comment:                    The following auxiliary datasets are used for...
#     creator_email:              kari.luojus@fmi.fi (Scientific and Production...
#     creator_name:               Finnish Meteorological Institute
#     creator_url:                www.fmi.fi
#     ...                         ...
#     time_coverage_duration:     P1D
#     time_coverage_end:          20200524T000000Z
#     time_coverage_resolution:   P1D
#     time_coverage_start:        19790102T000000Z
#     title:                      ESA CCI snow SWE product level L3C daily, Dyn...
#     tracking_id:                25063fb5-47ad-424a-8f26-29bdf35efb78

# %%
# %matplotlib inline
import xarray as xr
import matplotlib.pyplot as plt

swe_da = dataset["swe"]
swe_da
# Out:
# <xarray.DataArray 'swe' (time: 7934, lat: 1800, lon: 3600)> Size: 411GB
# dask.array<open_dataset-swe, shape=(7934, 1800, 3600), dtype=float64, chunksize=(10, 900, 900), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 14kB -89.95 -89.85 -89.75 ... 89.75 89.85 89.95
#   * lon      (lon) float64 29kB -179.9 -179.8 -179.8 ... 179.7 179.8 179.9
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24
# Attributes:
#     actual_range:         [1, 187]
#     ancillary_variables:  swe_std
#     flag_meanings:        Glacier Mountain Water no_data no_snow
#     flag_values:          [-30, -20, -10, -1, 0]
#     grid_mapping:         spatial_ref
#     long_name:            Snow Water Equivalent
#     units:                mm
#     valid_range:          [1, 500]

# %%
def plot_snow(da):
    fig, ax = plt.subplots(figsize=(10, 8))
    da.plot.imshow(
        ax=ax,
        cmap="gray",
        vmin=da.min().compute().item(),
        vmax=da.max().compute().item(),
        add_colorbar=True,
        yincrease=True,
    )
    ax.set_title("Snow Water Equivalent (SWE)")
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    plt.show()

# %%
plot_snow(swe_da.isel(time=0))

# %%
plot_snow(swe_da.isel(time=1000))

# %%
swe_uk_da = swe_da.sel({
    "lat": slice(49.959999905, 58.6350001085),
    "lon": slice(-7.57216793459, 1.68153079591)
})
swe_uk_da
# Out:
# <xarray.DataArray 'swe' (time: 7934, lat: 86, lon: 93)> Size: 508MB
# dask.array<getitem, shape=(7934, 86, 93), dtype=float64, chunksize=(10, 86, 76), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 688B 50.05 50.15 50.25 50.35 ... 58.35 58.45 58.55
#   * lon      (lon) float64 744B -7.55 -7.45 -7.35 -7.25 ... 1.35 1.45 1.55 1.65
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24
# Attributes:
#     actual_range:         [1, 187]
#     ancillary_variables:  swe_std
#     flag_meanings:        Glacier Mountain Water no_data no_snow
#     flag_values:          [-30, -20, -10, -1, 0]
#     grid_mapping:         spatial_ref
#     long_name:            Snow Water Equivalent
#     units:                mm
#     valid_range:          [1, 500]

# %%
plot_snow(swe_uk_da.isel(time=0))

# %%
print(swe_uk_da)
# Out:
# <xarray.DataArray 'swe' (time: 7934, lat: 86, lon: 93)> Size: 508MB
# dask.array<getitem, shape=(7934, 86, 93), dtype=float64, chunksize=(10, 86, 76), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 688B 50.05 50.15 50.25 50.35 ... 58.35 58.45 58.55
#   * lon      (lon) float64 744B -7.55 -7.45 -7.35 -7.25 ... 1.35 1.45 1.55 1.65
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24
# Attributes:
#     actual_range:         [1, 187]
#     ancillary_variables:  swe_std
#     flag_meanings:        Glacier Mountain Water no_data no_snow
#     flag_values:          [-30, -20, -10, -1, 0]
#     grid_mapping:         spatial_ref
#     long_name:            Snow Water Equivalent
#     units:                mm
#     valid_range:          [1, 500]

# %%
swe_uk_noflags_da = swe_uk_da.where(swe_uk_da >= 0)
swe_uk_noflags_da
# Out:
# <xarray.DataArray 'swe' (time: 7934, lat: 86, lon: 93)> Size: 508MB
# dask.array<where, shape=(7934, 86, 93), dtype=float64, chunksize=(10, 86, 76), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 688B 50.05 50.15 50.25 50.35 ... 58.35 58.45 58.55
#   * lon      (lon) float64 744B -7.55 -7.45 -7.35 -7.25 ... 1.35 1.45 1.55 1.65
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24
# Attributes:
#     actual_range:         [1, 187]
#     ancillary_variables:  swe_std
#     flag_meanings:        Glacier Mountain Water no_data no_snow
#     flag_values:          [-30, -20, -10, -1, 0]
#     grid_mapping:         spatial_ref
#     long_name:            Snow Water Equivalent
#     units:                mm
#     valid_range:          [1, 500]

# %%
area_avg = swe_uk_noflags_da.mean(dim=['lat', 'lon'], skipna=True)
area_avg
# Out:
# <xarray.DataArray 'swe' (time: 7934)> Size: 63kB
# dask.array<mean_agg-aggregate, shape=(7934,), dtype=float64, chunksize=(10,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24

# %%
area_avg.plot.line(marker='.', figsize=(12, 4))
plt.ylabel("Average SWE (mm)")
plt.title("Time series of average Snow Water Equivalent")
plt.grid()
plt.show()

# %%
area_avg_rolling_avg = area_avg.rolling(time=365, min_periods=1, center=False).mean()
area_avg_rolling_avg
# Out:
# <xarray.DataArray 'swe' (time: 7934)> Size: 63kB
# dask.array<truediv, shape=(7934,), dtype=float64, chunksize=(374,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24

# %%
area_avg_rolling_avg.plot.line(marker='.', figsize=(12, 4))
plt.ylabel("Average SWE (mm)")
plt.title("Time series of rolling yearly average Snow Water Equivalent")
plt.grid()
plt.show()

# %%
import duckdb

duckdb.sql("SELECT 42").show()
# Out:
# ┌───────┐
# │  42   │
# │ int32 │
# ├───────┤
# │    42 │
# └───────┘

# %%
duckdb.sql("INSTALL SPATIAL")

# %%
duckdb.sql("LOAD SPATIAL")

# %%
duckdb.sql(
"""
CREATE OR REPLACE VIEW division_area AS
SELECT
    *
FROM
    read_parquet('s3://overturemaps-us-west-2/release/2025-07-23.0/theme=divisions/type=division_area/*', 
                 hive_partitioning=1)
""")

# %%
duckdb.sql(
"""
SELECT id,bbox
FROM division_area
WHERE id='58a34fa4-bc76-476e-81a8-1ed8a5cd693f' -- edinburgh
"""
).show()
# Out:
# ┌──────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────┐
# │                  id                  │                                     bbox                                      │
# │               varchar                │            struct(xmin float, xmax float, ymin float, ymax float)             │
# ├──────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────┤
# │ 58a34fa4-bc76-476e-81a8-1ed8a5cd693f │ {'xmin': -3.4495325, 'xmax': -3.077676, 'ymin': 55.819736, 'ymax': 56.001587} │
# └──────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────┘

# %%
swe_edin_da = swe_da.sel({
    "lat": slice(55.819736, 56.001587),
    "lon": slice(-3.4495325, -3.077676)
})
swe_edin_da
# Out:
# <xarray.DataArray 'swe' (time: 7934, lat: 2, lon: 3)> Size: 381kB
# dask.array<getitem, shape=(7934, 2, 3), dtype=float64, chunksize=(10, 2, 3), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 16B 55.85 55.95
#   * lon      (lon) float64 24B -3.35 -3.25 -3.15
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24
# Attributes:
#     actual_range:         [1, 187]
#     ancillary_variables:  swe_std
#     flag_meanings:        Glacier Mountain Water no_data no_snow
#     flag_values:          [-30, -20, -10, -1, 0]
#     grid_mapping:         spatial_ref
#     long_name:            Snow Water Equivalent
#     units:                mm
#     valid_range:          [1, 500]

# %%
plot_snow(swe_edin_da.isel(time=0))

# %%
def plot_snow_over_time(da, window_size_in_days=365):
    noflags_da = da.where(da >= 0)
    area_avg = noflags_da.mean(dim=['lat', 'lon'], skipna=True)

    area_avg.plot.line(marker='.', figsize=(12, 4))
    plt.ylabel("Average SWE (mm)")
    plt.title("Time series of average Snow Water Equivalent")
    plt.grid()
    plt.show()

    area_avg_rolling_avg = area_avg.rolling(time=window_size_in_days, min_periods=1, center=False).mean()

    area_avg_rolling_avg.plot.line(marker='.', figsize=(12, 4))
    plt.ylabel("Average SWE (mm)")
    plt.title("Time series of rolling yearly average Snow Water Equivalent")
    plt.grid()
    plt.show()

# %%
plot_snow_over_time(swe_edin_da)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_snow_over_time(swe_edin_da)
#
# NameError: name 'swe_edin_da' is not defined

# %%
duckdb.sql(
"""
SELECT id,bbox
FROM division_area
WHERE id='32883d55-acaa-492e-94eb-fe8335ee5169' -- ronneburg
"""
).show()
# Out:
# ┌──────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────┐
# │                  id                  │                                   bbox                                    │
# │               varchar                │          struct(xmin float, xmax float, ymin float, ymax float)           │
# ├──────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────┤
# │ 32883d55-acaa-492e-94eb-fe8335ee5169 │ {'xmin': 12.135956, 'xmax': 12.221571, 'ymin': 50.82928, 'ymax': 50.8807} │
# └──────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────┘

# %%
swe_ronn_da = swe_da.sel({
    "lat": slice(50.82928, 50.8807),
    "lon": slice(12.135956, 12.221571)
})
swe_ronn_da
# Out:
# <xarray.DataArray 'swe' (time: 7934, lat: 1, lon: 1)> Size: 63kB
# dask.array<getitem, shape=(7934, 1, 1), dtype=float64, chunksize=(10, 1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 8B 50.85
#   * lon      (lon) float64 8B 12.15
#   * time     (time) datetime64[ns] 63kB 1979-01-02 1979-01-04 ... 2020-05-24
# Attributes:
#     actual_range:         [1, 187]
#     ancillary_variables:  swe_std
#     flag_meanings:        Glacier Mountain Water no_data no_snow
#     flag_values:          [-30, -20, -10, -1, 0]
#     grid_mapping:         spatial_ref
#     long_name:            Snow Water Equivalent
#     units:                mm
#     valid_range:          [1, 500]

# %%
plot_snow(swe_ronn_da.isel(time=0))

# %%
plot_snow_over_time(swe_ronn_da)
