# %%
from overturemaps import core

# %%
# Cambridge Kendall Square
bbox = (-71.0886055604, 42.3606368124, -71.0766325984, 42.3606368124)

# %%
gdf = core.geodataframe("segment", bbox=bbox)

# %%
gdf = gdf.set_crs("EPSG:4326")

# %%
gdf.head()
# Out:
#                                      id  \
# 0  a0ea5b52-a5b8-4ad5-842c-5f2ea1aa6ec7
# 1  b20e5a00-90a3-4d05-8b0f-1b8bbb7d937e
# 2  ddb7240e-be87-46be-8068-31c3e21498b3
# 3  c5a661c4-339f-4d89-a511-6c5771f2ac2a
# 4  1b3974f3-42f6-4f16-89ce-a241cd3c1fc5
#
#                                             geometry  \
# 0  LINESTRING (-71.11551 42.37213, -71.11529 42.3...
# 1  LINESTRING (-71.05547 42.3253, -71.05584 42.32...
# 2  LINESTRING (-71.0888 42.36072, -71.08872 42.36...
# 3  LINESTRING (-71.08737 42.35926, -71.08731 42.3...
# 4  LINESTRING (-71.08855 42.3608, -71.08848 42.36...
#
#                                                 bbox  version  \
# 0  {'xmin': -71.11550903320312, 'xmax': -71.05274...        2
# 1  {'xmin': -71.14348602294922, 'xmax': -71.05262...        1
# 2  {'xmin': -71.08880615234375, 'xmax': -71.08824...        1
# 3  {'xmin': -71.08827209472656, 'xmax': -71.08730...        1
# 4  {'xmin': -71.08855438232422, 'xmax': -71.08799...        1
#
#                                              sources subtype    class  \
# 0  [{'property': '', 'dataset': 'OpenStreetMap', ...    rail   subway
# 1  [{'property': '', 'dataset': 'OpenStreetMap', ...    rail   subway
# 2  [{'property': '', 'dataset': 'OpenStreetMap', ...    road  footway
# 3  [{'property': '', 'dataset': 'OpenStreetMap', ...    road  footway
# 4  [{'property': '', 'dataset': 'OpenStreetMap', ...    road  footway
#
#                                                names  \
# 0  {'primary': 'Red Line', 'common': None, 'rules...
# 1  {'primary': 'Red Line', 'common': None, 'rules...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                           connectors routes  ...  \
# 0  [{'connector_id': 'efe74c69-c38f-4d97-8eb2-892...   None  ...
# 1  [{'connector_id': '3fea074a-1da4-4b3a-a40a-84f...   None  ...
# 2  [{'connector_id': 'c5dc6178-d394-43f4-9641-bc6...   None  ...
# 3  [{'connector_id': '9e82023d-03ef-429b-a65e-e86...   None  ...
# 4  [{'connector_id': '90412f00-906a-4873-8315-3c7...   None  ...
#
#                                  access_restrictions  \
# 0                                               None
# 1                                               None
# 2  [{'access_type': 'allowed', 'when': {'during':...
# 3                                               None
# 4  [{'access_type': 'allowed', 'when': {'during':...
#
#                                          level_rules destinations  \
# 0  [{'value': -1, 'between': [0.0, 0.348468838]},...         None
# 1  [{'value': -2, 'between': [0.008996005, 0.3404...         None
# 2                                               None         None
# 3                                               None         None
# 4                                               None         None
#
#   prohibited_transitions                           road_surface road_flags  \
# 0                   None                                   None       None
# 1                   None                                   None       None
# 2                   None  [{'value': 'paved', 'between': None}]       None
# 3                   None  [{'value': 'paved', 'between': None}]       None
# 4                   None  [{'value': 'paved', 'between': None}]       None
#
#   speed_limits width_rules subclass  \
# 0         None        None     None
# 1         None        None     None
# 2         None        None     None
# 3         None        None     None
# 4         None        None     None
#
#                                           rail_flags
# 0  [{'values': ['is_tunnel'], 'between': [0.0, 0....
# 1  [{'values': ['is_covered', 'is_tunnel'], 'betw...
# 2                                               None
# 3                                               None
# 4                                               None
#
# [5 rows x 21 columns]

# %%
from lonboard import viz

# %%
viz(gdf)
# Out:
# Map(basemap_style=<CartoBasemap.DarkMatter: 'https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json'…
